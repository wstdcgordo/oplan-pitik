# %%
from barangay import search

# %%
results = search("Gulang-Gulang")
print(results[0]['barangay'])
# Out:
# Gulang-gulang

# %%
results
# Out:
# [{'barangay': 'Gulang-gulang',
#   'province_or_huc': 'City of Lucena',
#   'municipality_or_city': None,
#   'psgc_id': '0431200017',
#   'f_0p0b_ratio_score': 77.41935483870968,
#   'f_00mb_ratio_score': 82.75862068965517,
#   'f_0pmb_ratio_score': 66.66666666666667,
#   '000b': 'gulanggulang',
#   '0p0b': 'lucena gulanggulang',
#   '00mb': 'none gulanggulang',
#   '0pmb': 'lucena none gulanggulang'},
#  {'barangay': 'Gulang-Gulang',
#   'province_or_huc': 'Sorsogon',
#   'municipality_or_city': 'Irosin',
#   'psgc_id': '0506209012',
#   'f_0p0b_ratio_score': 72.72727272727273,
#   'f_00mb_ratio_score': 77.41935483870968,
#   'f_0pmb_ratio_score': 60.0,
#   '000b': 'gulanggulang',
#   '0p0b': 'sorsogon gulanggulang',
#   '00mb': 'irosin gulanggulang',
#   '0pmb': 'sorsogon irosin gulanggulang'},
#  {'barangay': 'Guilaoangi',
#   'province_or_huc': 'Northern Samar',
#   'municipality_or_city': 'Laoang',
#   'psgc_id': '0804808029',
#   'f_0p0b_ratio_score': 37.83783783783784,
# ...
